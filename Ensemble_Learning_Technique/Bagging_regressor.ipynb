# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.datasets import load_diabetes
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score

# %%
X,y=load_diabetes(return_X_y=True)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, y , train_size=0.80, test_size=0.20, random_state=123)

# %%
lr = LinearRegression()
dt = DecisionTreeRegressor()
knn = KNeighborsRegressor()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
dt.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor()

# %%
knn.fit(X_train,Y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred1 = lr.predict(X_test)
y_pred2 = dt.predict(X_test)
y_pred3 = knn.predict(X_test)

# %%
print("R^2 score for LR",r2_score(Y_test,y_pred1))
print("R^2 score for DT",r2_score(Y_test,y_pred2))
print("R^2 score for KNN",r2_score(Y_test,y_pred3))
# Out:
# R^2 score for LR 0.5675895725793205
# R^2 score for DT 0.11846822513458266
# R^2 score for KNN 0.438839665879189

# %%
from sklearn.ensemble import BaggingRegressor

bag_regressor = BaggingRegressor(random_state=1)
bag_regressor.fit(X_train, Y_train)
# Out:
# BaggingRegressor(random_state=1)

# %%
Y_preds = bag_regressor.predict(X_test)

print('Training Coefficient of R^2 : %.3f'%bag_regressor.score(X_train, Y_train))
print('Test Coefficient of R^2 : %.3f'%bag_regressor.score(X_test, Y_test))
# Out:
# Training Coefficient of R^2 : 0.897
# Test Coefficient of R^2 : 0.499

# %% [markdown]
# #### Bagging Regressor using Linear Regressor

# %%
bag=BaggingRegressor(
    estimator=LinearRegression(),
    n_estimators=500,
    max_samples=0.25,
    bootstrap=True,
    random_state=123
)

# %%
bag.fit(X_train,Y_train)
# Out:
# BaggingRegressor(estimator=LinearRegression(), max_samples=0.25,
#                  n_estimators=500, random_state=123)

# %%
y_predict=bag.predict(X_test)
r2_score(Y_test,y_predict)
# Out:
# 0.5673126798872774

# %% [markdown]
# #### Bagging Regressor using DecisionRegressor

# %%
bag=BaggingRegressor(
    estimator=DecisionTreeRegressor(),
    n_estimators=500,
    max_samples=0.25,
    bootstrap=True,
    random_state=123
)

# %%
bag.fit(X_train,Y_train)
# Out:
# BaggingRegressor(estimator=DecisionTreeRegressor(), max_samples=0.25,
#                  n_estimators=500, random_state=123)

# %%
y_predict=bag.predict(X_test)
r2_score(Y_test,y_predict)
# Out:
# 0.5569214660109068

# %% [markdown]
# #### Bagging Regressor using Knn

# %%
bag=BaggingRegressor(
    estimator=KNeighborsRegressor(),
    n_estimators=500,
    max_samples=0.25,
    bootstrap=True,
    random_state=123
)

# %%
bag.fit(X_train,Y_train)
# Out:
# BaggingRegressor(estimator=KNeighborsRegressor(), max_samples=0.25,
#                  n_estimators=500, random_state=123)

# %%
y_predict=bag.predict(X_test)
r2_score(Y_test,y_predict)
# Out:
# 0.48043691335511407
