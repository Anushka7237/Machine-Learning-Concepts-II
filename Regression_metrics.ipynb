# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
df=pd.read_csv('Datasets/placement.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
X=df.iloc[:,0:1]
y=df.iloc[:,-1]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
X_train.shape,X_test.shape
# Out:
# ((160, 1), (40, 1))

# %%
lr=LinearRegression()
lr.fit(X_train,y_train)
y_predict=lr.predict(X_test)

# %% [markdown]
# #### Mean_Absolute_Error

# %%
mae=mean_absolute_error(y_predict,y_test)
print(f"MAE is {mae}")
# Out:
# MAE is 0.2884710931878175

# %% [markdown]
# #### Mean_Squarred_Error

# %%
mse=mean_squared_error(y_predict,y_test)
print(f"MSE is {mse}")
# Out:
# MSE is 0.12129235313495527

# %% [markdown]
# #### Root_mean_squared_error

# %%
rmse=np.sqrt(mean_squared_error(y_predict,y_test))
print(f"RMSE is {rmse}")
# Out:
# RMSE is 0.34827051717731616

# %% [markdown]
# #### R2 Score

# %%
r2score=r2_score(y_predict,y_test)
print(f"R2 Score  is {r2score}")
# Out:
# R2 Score  is 0.6626575570753073

# %% [markdown]
# #### Adjusted R2 Score

# %%
n=X_test.shape[0]
k=X_test.shape[1]
adjusted_r2_score=1-((1-r2score)*(n-1)/(n-1-k))
print(f"Adjusted R2 Score  is {adjusted_r2_score}")
# Out:
# Adjusted R2 Score  is 0.6537801243667627
